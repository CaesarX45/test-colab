# %% [markdown]
# <a href="https://colab.research.google.com/github/CaesarX45/test-colab/blob/main/intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World")
# Out:
# Hello World

# %%
print("Hello Colab")
# Out:
# Hello Colab
